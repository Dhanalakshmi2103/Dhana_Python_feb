# %% [markdown]
# **Functions**
# block of code

# %% [markdown]
# **syntax**

# %%
#def <write your function name>:
    #<write your code>
#write addition program
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
def add():
    a=10
    b=20
    c=a+b
    print(c)

# %%
#in order to see the output we need to call the function
# function name is add

# %%
add
# Out:
# <function __main__.add()>

# %%
#whenever we see function
#whenever we see bound method
#then add normal brackets 
#functions or methods always with normal brackets only

# %%
add()
# Out:
# 30

# %%
#define the function
def add():
    a=10
    b=20
    c=a+b
    print(c)
#call the function
add()
# Out:
# 30

# %%
print(add())
#dont print the function name
#print is used for only see the output
# Out:
# 30
# None

# %%
def add1():
    a=eval(input('Enter a number1:'))
    b=eval(input('Enter a number2:'))
    c=a+b
    print(f"the addition of {a} and {b} is: {c}")
add1()
# Out:
# Enter a number1: 3
# Enter a number2: 5
# the addition of 3 and 5 is: 8

# %%
import random
def add1():
    a=random.randint(1,100)
    b=random.randint(2,200)
    add=a+b
    print(f"The addition of {a} and {b} is {add}")
add1()
# Out:
# The addition of 43 and 100 is 143

# %%
add1()
# Out:
# The addition of 15 and 90 is 105

# %% [markdown]
# - function name should not same as variable name
# - function name rules same as variable rules
# - function name and your file name should not be same
# - function name should not be same as package name

# %% [markdown]
# - when your define the function, if any error is there it will not show
# - If you want see the error or output
# - you need to call the function only

# %%
#wap ask the user take height of the traingle
breadth=float(input("Enter the breadth of the number:"))
height=float(input("Enter the height number:"))
area=breadth*height
print(f"The area of the right-angled triangle of breadth and height is:{area}")
# Out:
# Enter the breadth of the number: 34
# Enter the height number: 23
# The area of the right-angled triangle of breadth and height is:782.0

# %% [markdown]
# **Function With arguments**
#
# - First check how many variables are there inside the function
# - there are 3 varaibles
# - In the how many input varaibles are there:2 a,b
# - input variable means user will provide
# - here a,b provided by user only
# - In that how many output variables are there: 1 c
# - output variables are provided by code by using input variable
# - dont touch output variable

# %%
- some thing we are nit providing inside the brackets means
- it is called as Function with out arguments

# %%
def add(a,b):
    c=a+b
    print(c)
add(20,30)
# Out:
# 50

# %%
def average():
    a=eval(input('Enter a :'))
    b=eval(input('Enter b :'))
    c=eval(input('Enter c :'))
    avg=(a+b+c)/3
    avg1=round(avg,2)
    print(f"the average of {a} and {b} is: {c} is:",avg1)
average()
# Out:
# Enter a : 10
# Enter b : 30
# Enter c : 50
# the average of 10 and 30 is: 50 is: 30.0

# %%
#WAP ask the user take height of the traingle
#                       breadth of the traingle
# calculate the area  of the right angle traingle
# Formual: 1/2*b*h
def rec_area():
    length=30
    breadth=40
    area=length*breadth  
    print(f"The area of the rectangle  having {breadth},{length} is {area}")
    print("The area of the rectangle having {},{} is {}".format(breadth,length,area))
rec_area()
# Out:
# The area of the rectangle  having 40,30 is 1200
# The area of the rectangle having 40,30 is 1200

# %%
#Wap ask the user take the radius of circle
#    calculate the area of the circle
# Formula: pi*r*r  where pi=3.14
def circle():
    radius= 20
    pi=3.14
    area=pi*radius*radius
    print(f"The area of circle having {radius} is {area}")
    print("The area of a circle having {} is {}".format(radius,area))
circle()
# Out:
# The area of circle having 20 is 1256.0
# The area of a circle having 20 is 1256.0

# %%
#Wap ask the how much bill he wants to pay
#                how much tip percentage he wants to give
#                calculate the total bill amount

# bill amount =1000
#  you want give 10% tip = 1000*10/100
# total bill= 1000+100=1100
def bill_pay():
    bill_amount=1000
    tip_percentage=10
    tip_amount= bill_amount*tip_percentage/100
    total_bill= bill_amount+tip_amount
    print(f"The total bill is : {total_bill}")
bill_pay()
# Out:
# The total bill is : 1100.0

# %%
def area_of_tri(height,breadth):
    breadth=float(input("Enter the breadth of the number:"))
    height=float(input("Enter the height number:"))
    area=breadth*height
    print(f"The area of the right-angled triangle of breadth and height is:{area}")
area_of_tri(20,30)
# Out:
# Enter the breadth of the number: 20
# Enter the height number: 30
# The area of the right-angled triangle of breadth and height is:600.0

# %%
def circle(radius,pi):
    area=pi*radius*radius
    print(f"The area of circle having {radius} is {area}")
    print("The area of a circle having {} is {}".format(radius,area))
circle(30,3.14)
# Out:
# The area of circle having 30 is 2826.0
# The area of a circle having 30 is 2826.0

# %%
def rec_area(length,breadth):
    area=length*breadth  
    print(f"The area of the rectangle  having {breadth},{length} is {area}")
    print("The area of the rectangle having {},{} is {}".format(breadth,length,area))
rec_area(30,40)
# Out:
# The area of the rectangle  having 40,30 is 1200
# The area of the rectangle having 40,30 is 1200

# %%
def bill_pay( bill_amount,tip_percentage):
    tip_amount= bill_amount*tip_percentage/100
    total_bill= bill_amount+tip_amount
    print(f"The total bill is : {total_bill}")
bill_pay(100,35)
# Out:
# The total bill is : 135.0

# %%
def even_odd():
    num=eval(input('enter the number:'))
    if num%2==0:
        print(f'the {num} is an even')
    else:
        print(f' the {num} is an odd')
even_odd()
# Out:
# enter the number: 45
#  the 45 is an odd

# %%
def even_odd(num):
    if num%2==0:
        print(f'the {num} is an even')
    else:
        print(f' the {num} is an odd')
even_odd(23)
# Out:
#  the 23 is an odd

# %% [markdown]
# - try-exception should add inside the function call
# - we alredy know that,defining the function will not give any error

# %%
def even_odd(num):
    try:
        if num%2==0:
            print(f'the {num} is an even')
        else:
            print(f' the {num} is an odd')
    except Exception as e:
        print(e)
even_odd(23)
# Out:
#  the 23 is an odd

# %%
def average(a,b,c):
    try:
        average=(a+b+c)/3
        print(f"the average of {a} and {b} and {c} is:",average)
    except Exception as e:
        print(e)
average(10,20,30)
# Out:
# the average of 10 and 20 and 30 is: 20.0

# %%
def avg(a,b,c):
    print(f"the average of a is:",a)
    print(f"the average of b is:",b)
    print(f"the average of c is:",c)
    avg=(a+b+c)/3
    print(avg)
avg(10,20,34)
# Out:
# the average of a is: 10
# the average of b is: 20
# the average of c is: 34
# 21.333333333333332

# %% [markdown]
# - function without arguments
# - function with arguments

# %% [markdown]
# **Function with Default arguments**
# - There is a situtaion some variable values always a fixed
# - for example tip percentage for a hote it is fixed 20
# - these type variables are default parameters

# %%
def add(a,b,c=100):
    summ=a+b+c
    print(summ)
add(10,20,40)
# Out:
# 70

# %%
- while defineing function we will provide arguments
- at the time only we will provide value also
- that arguments is default argument 
- below examples there 3 arguments a,b,c
- but we given c=100 which means c is our default arguments
- once you provide the default arguments

# %%
def add(a,b,c=100):
    print("the value a is:",a)
    print("the value b is:",b)
    print("the value c is:",c)
    summ=a+b+c
    print(summ)
add(10,20)
# Out:
# the value a is: 10
# the value b is: 20
# the value c is: 100
# 130

# %%
#how many variables are there :3
#how many default arguments are there:1
#how many non default arguments are there:2
#how many values we need

# %% [markdown]
# **case-1**
# - Default arguments always at last
# - Do not provide in middile

# %%
def add(a,b=100,c):
    print("the value a is:",a)
    print("the value b is:",b)
    print("the value c is:",c)
    summ=a+b+c
    print(summ)
add(10,20)
# Out:
#   Cell In[39], line 1
#     def add(a,b=100,c):
#                     ^
# SyntaxError: non-default argument follows default argument

# %%
a,b,c=100
a,b=100,c
a=100,b,c
a,b,c=100
a=100,b,c=100
a=100,b=100,c=100
# Out:
#   Cell In[40], line 5
#     a=100,b,c=100
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %% [markdown]
# **case-2**

# %%
def add(a,b,c=100):
    print("the value a is:",a)
    print("the value b is:",b)
    print("the value c is:",c)
    summ=a+b+c
    print(summ)
add(10,20,200)
# Out:
# the value a is: 10
# the value b is: 20
# the value c is: 200
# 230

# %% [markdown]
# - if we alredy provide default value
# - But while calling the function again we are providing the value
# - the value will be over write
# - but while calling the function c=200
# - python is a step by step process
# - in above there 3 operations
#   - define the function
#   - call the function
#   - running the function
# - while define the function c=100
# - while call the function c=200
# - so the latest value is 200

# %%
def add(a,b,c=100):
    print('hai')
    c=10
    summ=a+b+c
    print(summ)
add(10,20,1000)
# Out:
# hai
# 40

# %% [markdown]
# - functioon with out arguments
# - functions with arguments
# - function with default arguments

# %%
def avg(a,b,c=100):
    avg=round(a+b+c)/3
    avg1=round(avg,2)
    print("The average of {a},{b} and )

# %%
def value(a=10):
    print(a)

# %%
value()
# Out:
# 10

# %% [markdown]
# **analogy with packages**

# %%
####################################################
# a data type is complex
#by default complex has real=0 img=0
#when we dont provide any value by default
#0+0j === > 0j
####################################################
#take your cursor inside the bracket
#apply shift+tab
##################################################
# If any function or method
#we dont give any values still is giving out put
#which means that functiion has default values

# %%
complex()
# Out:
# 0j

# %%
0+0j
o
0j
nt

# %%
#i want 2+3j
complex(2+3j,4)
# Out:
# (2+7j)

# %%
value(),value(100)
# Out:
# 10
# 100
# (None, None)

# %%
complex(2,2+4j,)
# Out:
# (-2+2j)

# %%
import random
random.randint(10,20)
# Out:
# 15

# %%
random.random()
# Out:
# 0.22420517235258275

# %%
def value1():
    print(100)
    
value1()
# Out:
# 100

# %%
- complex
- random.randint
- random.random

# %%
complex('2','2')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 complex('2','2')
#
# TypeError: complex() can't take second arg if first is a string

# %%
def value1():
    print(100)
    
value1()
# Out:
# 100

# %%
complex(2,2+4j)
# Out:
# (-2+2j)

# %%
4j*j ==== 4j^2 ===== 4*-1 === -4
2-4= -2
# Out:
#   Cell In[21], line 1
#     4j*j ==== 4j^2 ===== 4*-1 === -4
#            ^
# SyntaxError: invalid syntax

# %%
complex(3,2+4j)
# Out:
# (-1+2j)

# %%
2,2+4j
real=2
imaginary=2+4j
multiply imaginary value with j
(2+4j)j=2j+4*j2=2j+4(-1)=2

# %% [markdown]
# **global variable-local variable**

# %%
def add1():
    a=10
    b=20
    c=a+b
    print(c)
add1()
# Out:
# 30

# %%
a1=10
b1=20
def add2():
    c1=a1+b1
    print(c1)
add2()
# Out:
# 30

# %% [markdown]
# - variable inside function is called as **local variable**
# - variables outside function is called as **global ariable**
# - global variable can use any where at any time
# - imagine that ou created 10 functions all 10 functions using same variables
# - so why want intialize every time for every function
# - we will intialize one time at top,and all 10 functions will use the variables

# %%
def add():
    a=10
    b=20
    print(a+b)

def mul():
    a=10
    b=20
    print(a*b)
add()
mul()
# Out:
# 30
# 200

# %%
a=10
b=20
def add():
    print(a+b)


def mul():
    print(a*b)
add()
mul()
# Out:
# 30
# 200

# %%
c=500
def add(a,b,c=1000):
    summ=a+b+c

# %%
def bill_per(bill_amount,tip_per):
    tip_amount=bill_amount*tip_per/100
    total_bill=tip_amount+bill_amount
    return(tip_amount,total_bill)

total_bill=bill_pay(1000,10)
print("The total bill is:",total_bill)
# Out:
# The total bill is: (100.0, 1100.0)

# %%
def bill_per(bill_amount,tip_per):
    tip_amount=bill_amount*tip_per/100
    total_bill=tip_amount+bill_amount
    return(tip_amount,total_bill)

tip_amount,total_bill=bill_per(1000,10)
print("The total bill is:",total_bill)
# Out:
# The total bill is: 1100.0

# %%
def fun(a,b):
    a=10
    b=20
    return(a,b)

fun(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 6
#       3     b=20
#       4     return(a,b)
# ----> 6 fun(a)
#
# TypeError: fun() missing 1 required positional argument: 'b'

# %%
def bill_pay1():
    tip_amount1=bill_amount1*tip_per1/100
    total_bill1=tip_amount1+bill_amount1
    return(total_bill)
    
total_bill1=bill_pay1()

bill_amount1=eval(input())
tip_per1=eval(input())

print("The total bill is:",total_bill1)
#step_1:Define the function
#step_2:calling the function
#step_3:run the function
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 6
#       3     total_bill1=tip_amount1+bill_amount1
#       4     return(total_bill)
# ----> 6 total_bill1=bill_pay1()
#       8 bill_amount1=eval(input())
#       9 tip_per1=eval(input())
#
# Cell In[30], line 2, in bill_pay1()
#       1 def bill_pay1():
# ----> 2     tip_amount1=bill_amount1*tip_per1/100
#       3     total_bill1=tip_amount1+bill_amount1
#       4     return(total_bill)
#
# NameError: name 'bill_amount1' is not defined

# %% [markdown]
# - global variable can be intialise any where
# - by the time of the calling function
# - it variable are available or not?
# - if the variable are available then that function works

# %% [markdown]
# - function with arguments
# - funtion with out arguments
# - funtion with default arguments
# - local variable vs global variable
# - global key word
# - unbound local error
# - return
# - funtion in functions

# %%
def greet1():
    print('hello good moring')

def greet2():
    print('good nigh!')

greet1()
greet2()
# Out:
# hello good moring
# good nigh!

# %%
def greet1():
    print('hello good moring')

def greet2():
    print('good night!')
    greet1()


greet2()
#step-1: define the greet1
#step-2: define the greet2
#step-3: calling  the greet1()
#step-4: run the  greet1()
#      print ==== hello good mo
#      calling the greet2()
#      print ====== good night
# Out:
# good night!
# hello good moring

# %%
#########################################
def greet1():
    print('hello good moring')
    greet2()

def greet2():
    print('good night!')
    greet1()


greet2()
# Out:
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# hello good moring
# good night!
# ...

# %%
**task-1**
- create a function1
- take the 3 calues from user
- num1= eval (input()),num2= eval (input()),num3= eval (input())
- return those three values
- create a function2
- inside the function2 call the function1
- we alredy know function1 returning 3 values
- so here store in three variables
- and find the average and return it

# %%
def fun1():
    num1=eval(input("enter the value:"))
    num2=eval(input("enter the value:"))
    num3=eval(input("enter the value:"))
    return(num1,num2,num3)

def fun2():
    num1,num2,num3=fun1()
    avg=(num1+num2+num3)/3
    return(avg)

avg=fun2()
print(avg)
# Out:
# enter the value: 4
# enter the value: 5
# enter the value: 6
# 5.0

# %%
def fun1():
    num1=eval(input("enter the value:"))
    num2=eval(input("enter the value:"))
    num3=eval(input("enter the value:"))
    return(num1,num2,num3)

def average():
    num1,num2,num3=fun1()
    avg=(num1+num2+num3)/3
    return(avg)

avg=average()
print(avg)
# Out:
# enter the value: 2
# enter the value: 4
# enter the value: 5
# 3.6666666666666665

# %%
def fun1():
    num1=eval(input("enter the value:"))
    num2=eval(input("enter the value:"))
    num3=eval(input("enter the value:"))
    return(num1,num2,num3)

def average():
    num1,num2,num3=fun1()
    avg=(num1+num2+num3)/3
    return(avg)

def sum():
    num1,num2,num3=fun1()
    add=(num1+num2+num3)
    return(add)

def mul():
    num1,num2,num3=fun1()
    mul=(num1*num2*num3)
    return(mul)

def sub():
    num1,num2,num3=fun1()
    sub=(num1-num2-num3)
    return(sub)

def div():
    num1,num2,num3=fun1()
    div=(num1/num2/num3)
    return(mul)
    
    

avg=average()
print(avg)
# Out:
# enter the value: 2
# enter the value: 4
# enter the value: 5
# 3.6666666666666665

# %%
-create a add function 
   return the values
def add(a,b):
    return(a+b)
